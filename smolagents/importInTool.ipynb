# %%
from smolagents import CodeAgent, InferenceClientModel
import time
import datetime

# %%
agent = CodeAgent(tools=[],model=InferenceClientModel(),additional_authorized_imports=['datetime'])

# %%
agent.run(
    """
    Alfred need to prepare for the party. here are the tasks:
    1.prepare the drinks - 30 minutes.
    2.Decorate the mansion - 60 minutes.
    3. setup the meny -45 minutes.
    4. prepare the music and the playlist -45 minutes.

    if we start now, at what time on the clock will the party be ready?
    """
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Alfred need to prepare for the party. here are the tasks:                                                       │
# │     1.prepare the drinks - 30 minutes.                                                                          │
# │     2.Decorate the mansion - 60 minutes.                                                                        │
# │     3. setup the meny -45 minutes.                                                                              │
# │     4. prepare the music and the playlist -45 minutes.                                                          │
# │                                                                                                                 │
# │     if we start now, at what time on the clock will the party be ready?                                         │
# │                                                                                                                 │
# ╰─ InferenceClientModel - Qwen/Qwen3-Next-80B-A3B-Thinking ───────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   from datetime import datetime, timedelta
#   total_minutes = 30 + 60 + 45 + 45
#   current_time = datetime.now()
#   end_time = current_time + timedelta(minutes=total_minutes)
#   answer = end_time.strftime("%H:%M")
#   final_answer(answer)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: 02:03
# [Step 1: Duration 39.66 seconds| Input tokens: 2,109 | Output tokens: 5,809]
# '02:03'
