# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from PIL import Image
import requests
from io import BytesIO

image_urls = [
    "https://upload.wikimedia.org/wikipedia/commons/e/e8/The_Joker_at_Wax_Museum_Plus.jpg", # Joker image
    "https://upload.wikimedia.org/wikipedia/en/9/98/Joker_%28DC_Comics_character%29.jpg" # Joker image
]

images = []
for url in image_urls:
    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36" 
    }
    response = requests.get(url,headers=headers)
    image = Image.open(BytesIO(response.content)).convert("RGB")
    images.append(image)

# %%
import os
os.environ["OPENAI_API_KEY"] = ""

# %%
from smolagents import CodeAgent, OpenAIServerModel

model = OpenAIServerModel(model_id="gpt-4o")

# Instantiate the agent
agent = CodeAgent(
    tools=[],
    model=model,
    max_steps=20,
    verbosity_level=2
)

response = agent.run(
    """
    Describe the costume and makeup that the comic character in these photos is wearing and return the description.
    Tell me if the guest is The Joker or Wonder Woman.
    """,
    images=images
)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Describe the costume and makeup that the comic character in these photos is wearing and return the description. │
# │     Tell me if the guest is The Joker or Wonder Woman.                                                          │
# │                                                                                                                 │
# ╰─ OpenAIModel - gpt-4o ──────────────────────────────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# Error in generating model output:
# Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing
# details. For more information on this error, read the docs:
# https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None,
# 'code': 'insufficient_quota'}}
# [Step 1: Duration 641.69 seconds]
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/smolagents/agents.py:1662, in CodeAgent._step_stream(self, memory_step)
#    1661 else:
# -> 1662     chat_message: ChatMessage = self.model.generate(
#    1663         input_messages,
#    1664         stop_sequences=stop_sequences,
#    1665         **additional_args,
#    1666     )
#    1667     memory_step.model_output_message = chat_message
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/smolagents/models.py:1780, in OpenAIModel.generate(self, messages, stop_sequences, response_format, tools_to_call_from, **kwargs)
#    1779 self._apply_rate_limit()
# -> 1780 response = self.retryer(self.client.chat.completions.create, **completion_kwargs)
#    1781 content = response.choices[0].message.content
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/smolagents/utils.py:542, in Retrying.__call__(self, fn, *args, **kwargs)
#     541 try:
# --> 542     result = fn(*args, **kwargs)
#     544     # Log after successful call if we had retries
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/openai/_utils/_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/openai/resources/chat/completions/completions.py:1204, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 validate_response_format(response_format)
# -> 1204 return self._post(
#    1205     "/chat/completions",
#    1206     body=maybe_transform(
#    1207         {
#    1208             "messages": messages,
#    1209             "model": model,
#    1210             "audio": audio,
#    1211             "frequency_penalty": frequency_penalty,
#    1212             "function_call": function_call,
#    1213             "functions": functions,
#    1214             "logit_bias": logit_bias,
#    1215             "logprobs": logprobs,
#    1216             "max_completion_tokens": max_completion_tokens,
#    1217             "max_tokens": max_tokens,
#    1218             "metadata": metadata,
#    1219             "modalities": modalities,
#    1220             "n": n,
#    1221             "parallel_tool_calls": parallel_tool_calls,
#    1222             "prediction": prediction,
#    1223             "presence_penalty": presence_penalty,
#    1224             "prompt_cache_key": prompt_cache_key,
#    1225             "prompt_cache_retention": prompt_cache_retention,
#    1226             "reasoning_effort": reasoning_effort,
#    1227             "response_format": response_format,
#    1228             "safety_identifier": safety_identifier,
#    1229             "seed": seed,
#    1230             "service_tier": service_tier,
#    1231             "stop": stop,
#    1232             "store": store,
#    1233             "stream": stream,
#    1234             "stream_options": stream_options,
#    1235             "temperature": temperature,
#    1236             "tool_choice": tool_choice,
#    1237             "tools": tools,
#    1238             "top_logprobs": top_logprobs,
#    1239             "top_p": top_p,
#    1240             "user": user,
#    1241             "verbosity": verbosity,
#    1242             "web_search_options": web_search_options,
#    1243         },
#    1244         completion_create_params.CompletionCreateParamsStreaming
#    1245         if stream
#    1246         else completion_create_params.CompletionCreateParamsNonStreaming,
#    1247     ),
#    1248     options=make_request_options(
#    1249         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1250     ),
#    1251     cast_to=ChatCompletion,
#    1252     stream=stream or False,
#    1253     stream_cls=Stream[ChatCompletionChunk],
#    1254 )
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/openai/_base_client.py:1297, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1294 opts = FinalRequestOptions.construct(
#    1295     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1296 )
# -> 1297 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/openai/_base_client.py:1070, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1069     log.debug("Re-raising status error")
# -> 1070     raise self._make_status_error_from_response(err.response) from None
#    1072 break
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}
#
# The above exception was the direct cause of the following exception:
#
# AgentGenerationError                      Traceback (most recent call last)
# Cell In[8], line 13
#       5 # Instantiate the agent
#       6 agent = CodeAgent(
#       7     tools=[],
#       8     model=model,
#       9     max_steps=20,
#      10     verbosity_level=2
#      11 )
# ---> 13 response = agent.run(
#      14     """
#      15     Describe the costume and makeup that the comic character in these photos is wearing and return the description.
#      16     Tell me if the guest is The Joker or Wonder Woman.
#      17     """,
#      18     images=images
#      19 )
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/smolagents/agents.py:498, in MultiStepAgent.run(self, task, stream, reset, images, additional_args, max_steps, return_full_result)
#     495     return self._run_stream(task=self.task, max_steps=max_steps, images=images)
#     497 run_start_time = time.time()
# --> 498 steps = list(self._run_stream(task=self.task, max_steps=max_steps, images=images))
#     500 # Outputs are returned only at the end. We only look at the last step.
#     501 assert isinstance(steps[-1], FinalAnswerStep)
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/smolagents/agents.py:595, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     591             action_step.is_final_answer = True
#     593 except AgentGenerationError as e:
#     594     # Agent generation errors are not caused by a Model error but an implementation error: so we should raise them and exit.
# --> 595     raise e
#     596 except AgentError as e:
#     597     # Other AgentError types are caused by the Model, so we should log them and iterate.
#     598     action_step.error = e
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/smolagents/agents.py:577, in MultiStepAgent._run_stream(self, task, max_steps, images)
#     575 self.logger.log_rule(f"Step {self.step_number}", level=LogLevel.INFO)
#     576 try:
# --> 577     for output in self._step_stream(action_step):
#     578         # Yield all
#     579         yield output
#     581         if isinstance(output, ActionOutput) and output.is_final_answer:
#
# File ~/anaconda3/envs/agents/lib/python3.13/site-packages/smolagents/agents.py:1685, in CodeAgent._step_stream(self, memory_step)
#    1683     memory_step.model_output = output_text
#    1684 except Exception as e:
# -> 1685     raise AgentGenerationError(f"Error in generating model output:\n{e}", self.logger) from e
#    1687 ### Parse output ###
#    1688 try:
#
# AgentGenerationError: Error in generating model output:
# Error code: 429 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, read the docs: https://platform.openai.com/docs/guides/error-codes/api-errors.', 'type': 'insufficient_quota', 'param': None, 'code': 'insufficient_quota'}}

# %%
from smolagents import tool

@tool
def search_item_ctrl_f(text: str, nth_result: int = 1) -> str:
    """
    Searches for text on the current page via Ctrl + F and jumps to the nth occurrence.
    Args:
        text: The text to search for
        nth_result: Which occurrence to jump to (default: 1)
    """
    elements = driver.find_elements(By.XPATH, f"//*[contains(text(), '{text}')]")
    if nth_result > len(elements):
        raise Exception(f"Match n°{nth_result} not found (only {len(elements)} matches found)")
    result = f"Found {len(elements)} matches for '{text}'."
    elem = elements[nth_result - 1]
    driver.execute_script("arguments[0].scrollIntoView(true);", elem)
    result += f"Focused on element {nth_result} of {len(elements)}"
    return result


@tool
def go_back() -> None:
    """Goes back to previous page."""
    driver.back()


@tool
def close_popups() -> str:
    """
    Closes any visible modal or pop-up on the page. Use this to dismiss pop-up windows! This does not work on cookie consent banners.
    """
    webdriver.ActionChains(driver).send_keys(Keys.ESCAPE).perform()

# %%
def save_screenshot(step_log: ActionStep, agent: CodeAgent) -> None:
    sleep(1.0)  # Let JavaScript animations happen before taking the screenshot
    driver = helium.get_driver()
    current_step = step_log.step_number
    if driver is not None:
        for step_logs in agent.logs:  # Remove previous screenshots from logs for lean processing
            if isinstance(step_log, ActionStep) and step_log.step_number <= current_step - 2:
                step_logs.observations_images = None
        png_bytes = driver.get_screenshot_as_png()
        image = Image.open(BytesIO(png_bytes))
        print(f"Captured a browser screenshot: {image.size} pixels")
        step_log.observations_images = [image.copy()]  # Create a copy to ensure it persists, important!

    # Update observations with current URL
    url_info = f"Current url: {driver.current_url}"
    step_log.observations = url_info if step_logs.observations is None else step_log.observations + "\n" + url_info
    return
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 def save_screenshot(step_log: ActionStep, agent: CodeAgent) -> None:
#       2     sleep(1.0)  # Let JavaScript animations happen before taking the screenshot
#       3     driver = helium.get_driver()
#
# NameError: name 'ActionStep' is not defined

# %%
from smolagents import CodeAgent, OpenAIServerModel, DuckDuckGoSearchTool
model = OpenAIServerModel(model_id="gpt-4o")

agent = CodeAgent(
    tools=[DuckDuckGoSearchTool(), go_back, close_popups, search_item_ctrl_f],
    model=model,
    additional_authorized_imports=["helium"],
    step_callbacks=[save_screenshot],
    max_steps=20,
    verbosity_level=2,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 8
#       1 from smolagents import CodeAgent, OpenAIServerModel, DuckDuckGoSearchTool
#       2 model = OpenAIServerModel(model_id="gpt-4o")
#       4 agent = CodeAgent(
#       5     tools=[DuckDuckGoSearchTool(), go_back, close_popups, search_item_ctrl_f],
#       6     model=model,
#       7     additional_authorized_imports=["helium"],
# ----> 8     step_callbacks=[save_screenshot],
#       9     max_steps=20,
#      10     verbosity_level=2,
#      11 )
#
# NameError: name 'save_screenshot' is not defined

# %%
agent.run("""
I am Alfred, the butler of Wayne Manor, responsible for verifying the identity of guests at party. A superhero has arrived at the entrance claiming to be Wonder Woman, but I need to confirm if she is who she says she is.

Please search for images of Wonder Woman and generate a detailed visual description based on those images. Additionally, navigate to Wikipedia to gather key details about her appearance. With this information, I can determine whether to grant her access to the event.
""" + helium_instructions)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 5
#       1 agent.run("""
#       2 I am Alfred, the butler of Wayne Manor, responsible for verifying the identity of guests at party. A superhero has arrived at the entrance claiming to be Wonder Woman, but I need to confirm if she is who she says she is.
#       3
#       4 Please search for images of Wonder Woman and generate a detailed visual description based on those images. Additionally, navigate to Wikipedia to gather key details about her appearance. With this information, I can determine whether to grant her access to the event.
# ----> 5 """ + helium_instructions)
#
# NameError: name 'helium_instructions' is not defined
