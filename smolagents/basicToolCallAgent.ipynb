# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model = InferenceClientModel(
    model_id="mistralai/Mistral-7B-Instruct-v0.2"
)

# %%
from smolagents import ToolCallingAgent, WebSearchTool, InferenceClientModel

agent = ToolCallingAgent(tools=[WebSearchTool()],model=model)

agent.run("Search for the best music recommendation for a Holi party")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendation for a Holi party                                                       │
# │                                                                                                                 │
# ╰─ InferenceClientModel - mistralai/Mistral-7B-Instruct-v0.2 ─────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'web_search' with arguments: {'query': {'type': 'string', 'description': 'The search query to     │
# │ perform.'}}                                                                                                     │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Argument query has type 'object' but should be 'string'
# [Step 1: Duration 7.32 seconds| Input tokens: 1,050 | Output tokens: 52]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'web_search' with arguments: {'query': 'best music for a Holi party'}                             │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: ## Search Results
#
# |Non Stop Holi Songs Playlist | Holi Songs Bollywood | Holi 2026 | Holi
# ...](https://www.youtube.com/watch?v=8wNVFLuoB-w)
# Get ready to splash into colors and celebration with this Holi Mix Playlist Songs collection! 🎨🔥 Enjoy the
# ultimate lineup of Nonstop Hindi Holi Songs and ...
#
# |20+ Best Bollywood Holi Songs 2026: The Ultimate Party
# Playlist](https://www.winni.in/celebrate-relations/best-bollywood-holi-songs/)
# Get the ultimate 2026 Bollywood Holi songs playlist! From classic hits to new tracks, find the perfect music  for
# your Holi  party at Winni.
#
# |Best Bollywood Holi songs for your ultimate party
# playlist](https://www.indiatoday.in/information/story/best-bollywood-holi-songs-for-your-ultimate-party-playlist-28
# 76879-2026-03-03)
# From Rang Barse to Balam Pichkari, explore the best Bollywood Holi songs to add to your Holi  party playlist and
# celebrate the festival of colours with music , dance and nostalgia.
#
# |39 Best Holi Songs to Make Your Festival More
# Colorful](https://blog.grabon.in/best-holi-songs-uplift-festive-mood/)
# Get in the festive mood by tuning to these popular Holi songs that are certain to set your feet moving and your
# head spinning.
#
# |10 Holi Songs That Will Get Everyone Dancing Nonstop In Your Holi
# Party](https://www.missmalini.com/10-holi-songs-will-get-everyone-dancing-nonstop)
# Celebrate Holi with these 10 energetic songs. Perfect for dancing, throwing colors, and making your Holi  party fun
# and unforgettable.
#
# |Celebrate Holi with These Top 10 Must-Listen
# Songs](https://top10sense.com/celebrate-holi-with-these-top-10-must-listen-songs/)
# Top 10 Holi Songs to Elevate Your Festival Experience Holi celebrations are incomplete without the perfect blend of
# music and color. The right playlist can transform your Holi  party into an unforgettable experience, filled with
# energy and joy. Criteria for the Ultimate Holi Playlist Creating the perfect Holi playlist involves more than just
# picking popular tracks. Here's what makes a song a ...
#
# |Top 34 Songs to Make Your Holi More Colourful This
# Year.](https://www.groovenexus.com/top-playlist/top-holi-songs/)
#  Music is an expression of emotions and here we are with the top 34 Holi songs for making your Holi celebrations
# memorable with friends and family.
#
# |Bollywood Holi Song Playlist: Try These Hits at Your Holi
# Party](https://indian.community/bollywood-holi-songs-playlist-best-holi-dance-tracks/)
# Get ready for Holi with the ultimate Bollywood Holi songs playlist! From timeless hits like "Rang Barse" to modern
# beats like "Balam Pichkari," these tracks will set the perfect festive mood.
#
# |Holi Songs 2026: Best Bollywood Party Songs & Evergreen Classics
# ...](https://www.outlookindia.com/art-entertainment/holi-songs-2026-best-bollywood-party-songs-evergreen-classics-p
# laylist)
# From 'Holi Ke Din' and 'Rang Barse' to 'Balam Pichkari' and 'Panwadi', here are six Bollywood songs that perfectly
# capture the joy, nostalgia, and high-energy spirit of Holi 2026.
#
# |Top Bollywood Holi Songs 2026: From Rang Barse to Balam Pichkari for
# ...](https://www.etnownews.com/entertainment/bollywood-holi-songs-playlist-2026-from-rang-barse-to-balam-pichkari-u
# ltimate-party-anthems-for-a-colourful-celebration-article-153735800)
# Bollywood has given countless songs that make Holi celebrations colourful and full of energy, from timeless
# classics like Rang Barse to modern hits like Balam Pichkari. These tracks, old and new, are perfect for dancing,
# throwing colours, and bringing friends and family together during the festival.
# [Step 2: Duration 7.27 seconds| Input tokens: 2,208 | Output tokens: 86]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer': 'I recommend a playlist of the mentioned songs for your │
# │ Holi party.'}                                                                                                   │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: I recommend a playlist of the mentioned songs for your Holi party.
# Final answer: I recommend a playlist of the mentioned songs for your Holi party.
# [Step 3: Duration 14.23 seconds| Input tokens: 4,617 | Output tokens: 402]
# 'I recommend a playlist of the mentioned songs for your Holi party.'
